# %% [markdown]
# <a href="https://colab.research.google.com/github/sufiyan0/python/blob/main/practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
display("test")
# Out:
# 'test'

# %%
# !pip install mypy
# Out:
# Collecting mypy
#   Downloading mypy-1.6.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 27.7 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from mypy) (4.5.0)
# Collecting mypy-extensions>=1.0.0 (from mypy)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Requirement already satisfied: tomli>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from mypy) (2.0.1)
# Installing collected packages: mypy-extensions, mypy
# Successfully installed mypy-1.6.1 mypy-extensions-1.0.0

# %%
a= []

display([i for i in  dir(a) if "__" not in i])
# Out:
# ['append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
import pandas as pd
from scipy.cluster.hierarchy import dendrogram, linkage
import matplotlib.pyplot as plt

data = pd.read_csv('/content/cluster_data.csv')


linked = linkage(data, 'median')


dendrogram(linked, orientation='top', distance_sort='descending', show_leaf_counts=True)

plt.title('Dendrogram method = median')
plt.xlabel('Sample Index')
plt.ylabel('Cluster Distance')
plt.show()

# %%
import pandas as pd
from scipy.cluster.hierarchy import dendrogram, linkage
import matplotlib.pyplot as plt

data = pd.read_csv('/content/cluster_data.csv')


linked = linkage(data, 'complete')


dendrogram(linked, orientation='top', distance_sort='descending', show_leaf_counts=True)

plt.title('Dendrogram method = complete')
plt.xlabel('Sample Index')
plt.ylabel('Cluster Distance')
plt.show()

# %%
import pandas as pd
from scipy.cluster.hierarchy import dendrogram, linkage
import matplotlib.pyplot as plt

data = pd.read_csv('/content/cluster_data.csv')


linked = linkage(data, 'single')


dendrogram(linked, orientation='top', distance_sort='descending', show_leaf_counts=True)

plt.title('Dendrogram method = single')
plt.xlabel('Sample Index')
plt.ylabel('Cluster Distance')
plt.show()

# %%
import pandas as pd
from scipy.cluster.hierarchy import dendrogram, linkage
import matplotlib.pyplot as plt

data = pd.read_csv('/content/cluster_data.csv')


linked = linkage(data, 'average')


dendrogram(linked, orientation='top', distance_sort='descending', show_leaf_counts=True)

plt.title('Dendrogram method = average')
plt.xlabel('Sample Index')
plt.ylabel('Cluster Distance')
plt.show()

# %%
import pandas as pd
from scipy.cluster.hierarchy import dendrogram, linkage
import matplotlib.pyplot as plt

data = pd.read_csv('/content/cluster_data.csv')


linked = linkage(data, 'centroid')


dendrogram(linked, orientation='top', distance_sort='descending', show_leaf_counts=True)

plt.title('Dendrogram method = centroid')
plt.xlabel('Sample Index')
plt.ylabel('Cluster Distance')
plt.show()
